# %% [markdown]
# some playing around based on https://qrules.readthedocs.io/en/stable/usage/reaction.html

# %%
import qrules
from qrules.topology import Topology, Edge
from qrules import StateTransitionManager
from qrules.settings import InteractionType
from qrules.particle import Particle, load_pdg

# %% [markdown]
# I'm trying to simulate $p+p \rightarrow d + e^+ + \nu_e$
#
# $d$ is not in the PDG database, we have to define it ourselves

# %%
particle_db = load_pdg()
d = Particle(
    name="d",
    pid=9999999,
    mass=1.87561294257,  # gev
    spin=1,
    isospin=(0, 0),
    c_parity=+1,
    # baryon_number=2,
)
particle_db.add(d)

# %% [markdown]
# first, a topology needs to be defined

# %%
topology = Topology(
    nodes=[0, 1],
    edges=enumerate(
        [
            Edge(None, 0),  # p
            Edge(None, 0),  # p
            Edge(1, None),  # d
            Edge(1, None),  # e^+
            Edge(1, None),  # nu
            Edge(0, 1),
        ],
        -2  # start of the enumeration
    )
)

# %%
# visualize the topology
import graphviz

dot = qrules.io.asdot(
    topology,
    render_resonance_id=True,
    render_node=True,
    render_initial_state_id=True,
)
graphviz.Source(dot)

# %% [markdown]
# does this make sense? maybe, since this is also not a strict feynman diagram, should we ignore the 3-edge and have just one node?
#
# create a statetransition manager:

# %%
stm = StateTransitionManager(
    initial_state=["p", "p"],
    final_state=["d", "e+", "nu(e)"],
    particle_db=particle_db
)
stm.set_allowed_interaction_types([InteractionType.WEAK])
stm.topologies = (topology,)

# %%
problem_sets = stm.create_problem_sets()
problem_sets
# Out:
# defaultdict(list,
#             {1e-08: [ProblemSet(
#                 topology=Topology(
#                   nodes=frozenset({0, 1}),
#                   edges=FrozenDict({
#                     -2: Edge(originating_node_id=None, ending_node_id=0),
#                     -1: Edge(originating_node_id=None, ending_node_id=0),
#                     0: Edge(originating_node_id=1, ending_node_id=None),
#                     1: Edge(originating_node_id=1, ending_node_id=None),
#                     2: Edge(originating_node_id=1, ending_node_id=None),
#                     3: Edge(originating_node_id=0, ending_node_id=1),
#                   }),
#                 ),
#                 initial_facts=MutableTransition(
#                   topology=Topology(
#                     nodes=frozenset({0, 1}),
#                     edges=FrozenDict({
#                       -2: Edge(originating_node_id=None, ending_node_id=0),
#                       -1: Edge(originating_node_id=None, ending_node_id=0),
#                       0: Edge(originating_node_id=1, ending_node_id=None),
#                       1: Edge(originating_node_id=1, ending_node_id=None),
#                       2: Edge(originating_node_id=1, ending_node_id=None),
#                       3: Edge(originating_node_id=0, ending_node_id=1),
#                     }),
#                   ),
#                   states={-2: (Particle(
#                       name='p',
#                       pid=2212,
#                       latex='p',
#                       spin=0.5,
#                       mass=0.93827208816,
#                       charge=1,
#                       isospin=Spin(1/2, +1/2),
#                       baryon_number=1,
#                       parity=+1,
#                     ),
#                     -0.5),
#                    -1: (Particle(
#                       name='p',
#                       pid=2212,
#                       latex='p',
#                       spin=0.5,
#                       mass=0.93827208816,
#                       charge=1,
#                       isospin=Spin(1/2, +1/2),
#                       baryon_number=1,
#                       parity=+1,
#                     ),
#                     -0.5),
#                    0: (Particle(
#                       name='d',
#                       pid=9999999,
#                       spin=1.0,
#                       mass=1.87561294257,
#                       isospin=Spin(0, 0),
#                       c_parity=+1,
#                     ),
#                     -1.0),
#                    1: (Particle(
#                       name='e+',
#                       pid=-11,
#                       latex='e^{+}',
#                       spin=0.5,
#                       mass=0.0005109989499999999,
#                       charge=1,
#                       electron_lepton_number=-1,
#                       parity=-1,
#                     ),
#                     -0.5),
#                    2: (Particle(
#                       name='nu(e)',
#                       pid=12,
#                       latex='\\nu_{e}',
#                       spin=0.5,
#                       mass=0.0,
#                       electron_lepton_number=1,
#                       parity=+1,
#                     ),
#                     -0.5)},
#                   interactions={},
#                 ),
#                 solving_settings=MutableTransition(
#                   topology=Topology(
#                     nodes=frozenset({0, 1}),
#                     edges=FrozenDict({
#                       -2: Edge(originating_node_id=None, ending_node_id=0),
#                       -1: Edge(originating_node_id=None, ending_node_id=0),
#                       0: Edge(originating_node_id=1, ending_node_id=None),
#                       1: Edge(originating_node_id=1, ending_node_id=None),
#                       2: Edge(originating_node_id=1, ending_node_id=None),
#                       3: Edge(originating_node_id=0, ending_node_id=1),
#                     }),
#                   ),
#                   states={-2: EdgeSettings(
#                      conservation_rules={<function qrules.conservation_rules.gellmann_nishijima(edge_qns: qrules.conservation_rules.GellMannNishijimaInput) -> bool>,
#                       <function qrules.conservation_rules.isospin_validity(isospin: qrules.conservation_rules.IsoSpinEdgeInput) -> bool>,
#                       <function qrules.conservation_rules.spin_validity(spin: qrules.conservation_rules.SpinEdgeInput) -> bool>},
#                      rule_priorities={<function qrules.conservation_rules.gellmann_nishijima(edge_qns: qrules.conservation_rules.GellMannNishijimaInput) -> bool>: 50,
#                       <function qrules.conservation_rules.isospin_validity(isospin: qrules.conservation_rules.IsoSpinEdgeInput) -> bool>: 61,
#                       <function qrules.conservation_rules.spin_validity(spin: qrules.conservation_rules.SpinEdgeInput) -> bool>: 62},
#                      qn_domains={},
#                    ),
#                    -1: EdgeSettings(
#                      conservation_rules={<function qrules.conservation_rules.gellmann_nishijima(edge_qns: qrules.conservation_rules.GellMannNishijimaInput) -> bool>,
#                       <function qrules.conservation_rules.isospin_validity(isospin: qrules.conservation_rules.IsoSpinEdgeInput) -> bool>,
#                       <function qrules.conservation_rules.spin_validity(spin: qrules.conservation_rules.SpinEdgeInput) -> bool>},
#                      rule_priorities={<function qrules.conservation_rules.gellmann_nishijima(edge_qns: qrules.conservation_rules.GellMannNishijimaInput) -> bool>: 50,
#                       <function qrules.conservation_rules.isospin_validity(isospin: qrules.conservation_rules.IsoSpinEdgeInput) -> bool>: 61,
#                       <function qrules.conservation_rules.spin_validity(spin: qrules.conservation_rules.SpinEdgeInput) -> bool>: 62},
#                      qn_domains={},
#                    ),
#                    0: EdgeSettings(
#                      conservation_rules={<function qrules.conservation_rules.gellmann_nishijima(edge_qns: qrules.conservation_rules.GellMannNishijimaInput) -> bool>,
#                       <function qrules.conservation_rules.isospin_validity(isospin: qrules.conservation_rules.IsoSpinEdgeInput) -> bool>,
#                       <function qrules.conservation_rules.spin_validity(spin: qrules.conservation_rules.SpinEdgeInput) -> bool>},
#                      rule_priorities={<function qrules.conservation_rules.gellmann_nishijima(edge_qns: qrules.conservation_rules.GellMannNishijimaInput) -> bool>: 50,
#                       <function qrules.conservation_rules.isospin_validity(isospin: qrules.conservation_rules.IsoSpinEdgeInput) -> bool>: 61,
#                       <function qrules.conservation_rules.spin_validity(spin: qrules.conservation_rules.SpinEdgeInput) -> bool>: 62},
#                      qn_domains={},
#                    ),
#                    1: EdgeSettings(
#                      conservation_rules={<function qrules.conservation_rules.gellmann_nishijima(edge_qns: qrules.conservation_rules.GellMannNishijimaInput) -> bool>,
#                       <function qrules.conservation_rules.isospin_validity(isospin: qrules.conservation_rules.IsoSpinEdgeInput) -> bool>,
#                       <function qrules.conservation_rules.spin_validity(spin: qrules.conservation_rules.SpinEdgeInput) -> bool>},
#                      rule_priorities={<function qrules.conservation_rules.gellmann_nishijima(edge_qns: qrules.conservation_rules.GellMannNishijimaInput) -> bool>: 50,
#                       <function qrules.conservation_rules.isospin_validity(isospin: qrules.conservation_rules.IsoSpinEdgeInput) -> bool>: 61,
#                       <function qrules.conservation_rules.spin_validity(spin: qrules.conservation_rules.SpinEdgeInput) -> bool>: 62},
#                      qn_domains={},
#                    ),
#                    2: EdgeSettings(
#                      conservation_rules={<function qrules.conservation_rules.gellmann_nishijima(edge_qns: qrules.conservation_rules.GellMannNishijimaInput) -> bool>,
#                       <function qrules.conservation_rules.isospin_validity(isospin: qrules.conservation_rules.IsoSpinEdgeInput) -> bool>,
#                       <function qrules.conservation_rules.spin_validity(spin: qrules.conservation_rules.SpinEdgeInput) -> bool>},
#                      rule_priorities={<function qrules.conservation_rules.gellmann_nishijima(edge_qns: qrules.conservation_rules.GellMannNishijimaInput) -> bool>: 50,
#                       <function qrules.conservation_rules.isospin_validity(isospin: qrules.conservation_rules.IsoSpinEdgeInput) -> bool>: 61,
#                       <function qrules.conservation_rules.spin_validity(spin: qrules.conservation_rules.SpinEdgeInput) -> bool>: 62},
#                      qn_domains={},
#                    ),
#                    3: EdgeSettings(
#                      conservation_rules={<function qrules.conservation_rules.gellmann_nishijima(edge_qns: qrules.conservation_rules.GellMannNishijimaInput) -> bool>,
#                       <function qrules.conservation_rules.isospin_validity(isospin: qrules.conservation_rules.IsoSpinEdgeInput) -> bool>,
#                       <function qrules.conservation_rules.spin_validity(spin: qrules.conservation_rules.SpinEdgeInput) -> bool>},
#                      rule_priorities={<function qrules.conservation_rules.gellmann_nishijima(edge_qns: qrules.conservation_rules.GellMannNishijimaInput) -> bool>: 50,
#                       <function qrules.conservation_rules.isospin_validity(isospin: qrules.conservation_rules.IsoSpinEdgeInput) -> bool>: 61,
#                       <function qrules.conservation_rules.spin_validity(spin: qrules.conservation_rules.SpinEdgeInput) -> bool>: 62},
#                      qn_domains={qrules.quantum_numbers.EdgeQuantumNumbers.electron_lepton_number: [-1,
#                        0,
#                        1],
#                       qrules.quantum_numbers.EdgeQuantumNumbers.muon_lepton_number: [-1,
#                        0,
#                        1],
#                       qrules.quantum_numbers.EdgeQuantumNumbers.tau_lepton_number: [-1,
#                        0,
#                        1],
#                       qrules.quantum_numbers.EdgeQuantumNumbers.parity: [-1,
#                        1],
#                       qrules.quantum_numbers.EdgeQuantumNumbers.c_parity: [-1,
#                        1,
#                        None],
#                       qrules.quantum_numbers.EdgeQuantumNumbers.g_parity: [-1,
#                        1,
#                        None],
#                       qrules.quantum_numbers.EdgeQuantumNumbers.charge: [-2,
#                        -1,
#                        0,
#                        1,
#                        2],
#                       qrules.quantum_numbers.EdgeQuantumNumbers.baryon_number: [-1,
#                        0,
#                        1],
#                       qrules.quantum_numbers.EdgeQuantumNumbers.strangeness: [-3,
#                        -2,
#                        -1,
#                        0,
#                        1,
#                        2,
#                        3],
#                       qrules.quantum_numbers.EdgeQuantumNumbers.charmness: [-1,
#                        0,
#                        1],
#                       qrules.quantum_numbers.EdgeQuantumNumbers.bottomness: [-1,
#                        0,
#                        1],
#                       qrules.quantum_numbers.EdgeQuantumNumbers.spin_magnitude: [0,
#                        0.5,
#                        1,
#                        1.5,
#                        2,
#                        2.5,
#                        3,
#                        3.5,
#                        4],
#                       qrules.quantum_numbers.EdgeQuantumNumbers.spin_projection: [-4,
#                        -3.5,
#                        -3,
#                        -2.5,
#                        -2,
#                        -1.5,
#                        -1,
#                        -0.5,
#                        0,
#                        0.5,
#                        1,
#                        1.5,
#                        2,
#                        2.5,
#                        3,
#                        3.5,
#                        4],
#                       qrules.quantum_numbers.EdgeQuantumNumbers.isospin_magnitude: [0,
#                        0.5,
#                        1,
#                        1.5],
#                       qrules.quantum_numbers.EdgeQuantumNumbers.isospin_projection: [-1.5,
#                        -1,
#                        -0.5,
#                        0,
#                        0.5,
#                        1,
#                        1.5]},
#                    )},
#                   interactions={0: NodeSettings(
#                      conservation_rules={<function qrules.conservation_rules.helicity_conservation(ingoing_spin_mags: List[qrules.quantum_numbers.EdgeQuantumNumbers.spin_magnitude], outgoing_helicities: List[qrules.quantum_numbers.EdgeQuantumNumbers.spin_projection]) -> bool>,
#                       <function qrules.conservation_rules.identical_particle_symmetrization(ingoing_parities: List[qrules.quantum_numbers.EdgeQuantumNumbers.parity], outgoing_edge_qns: List[qrules.conservation_rules.IdenticalParticleSymmetryOutEdgeInput]) -> bool>,
#                       <function qrules.conservation_rules.spin_magnitude_conservation(ingoing_spins: List[qrules.conservation_rules.SpinEdgeInput], outgoing_spins: List[qrules.conservation_rules.SpinEdgeInput], interaction_qns: qrules.conservation_rules.SpinMagnitudeNodeInput) -> bool>,
#                       <qrules.conservation_rules.BaryonNumberConservation at 0x15071ca27400>,
#                       <qrules.conservation_rules.ChargeConservation at 0x15071ca272b0>,
#                       <qrules.conservation_rules.ElectronLNConservation at 0x15071ca273a0>,
#                       <qrules.conservation_rules.MassConservation at 0x15071ca27460>,
#                       <qrules.conservation_rules.MuonLNConservation at 0x15071ca27340>,
#                       <qrules.conservation_rules.TauLNConservation at 0x15071cd1f4c0>},
#                      rule_priorities={qrules.conservation_rules.MassConservation: 10,
#                       qrules.conservation_rules.ElectronLNConservation: 45,
#                       qrules.conservation_rules.MuonLNConservation: 44,
#                       qrules.conservation_rules.TauLNConservation: 43,
#                       qrules.conservation_rules.BaryonNumberConservation: 90,
#                       qrules.conservation_rules.StrangenessConservation: 69,
#                       qrules.conservation_rules.CharmConservation: 70,
#                       qrules.conservation_rules.BottomnessConservation: 68,
#                       qrules.conservation_rules.ChargeConservation: 100,
#                       <function qrules.conservation_rules.spin_conservation(ingoing_spins: List[qrules.conservation_rules.SpinEdgeInput], outgoing_spins: List[qrules.conservation_rules.SpinEdgeInput], interaction_qns: qrules.conservation_rules.SpinNodeInput) -> bool>: 8,
#                       <function qrules.conservation_rules.spin_magnitude_conservation(ingoing_spins: List[qrules.conservation_rules.SpinEdgeInput], outgoing_spins: List[qrules.conservation_rules.SpinEdgeInput], interaction_qns: qrules.conservation_rules.SpinMagnitudeNodeInput) -> bool>: 8,
#                       <function qrules.conservation_rules.parity_conservation(ingoing_edge_qns: List[qrules.quantum_numbers.EdgeQuantumNumbers.parity], outgoing_edge_qns: List[qrules.quantum_numbers.EdgeQuantumNumbers.parity], l_magnitude: qrules.quantum_numbers.NodeQuantumNumbers.l_magnitude) -> bool>: 6,
#                       <function qrules.conservation_rules.c_parity_conservation(ingoing_edge_qns: List[qrules.conservation_rules.CParityEdgeInput], outgoing_edge_qns: List[qrules.conservation_rules.CParityEdgeInput], interaction_node_qns: qrules.conservation_rules.CParityNodeInput) -> bool>: 5,
#                       <function qrules.conservation_rules.g_parity_conservation(ingoing_edge_qns: List[qrules.conservation_rules.GParityEdgeInput], outgoing_edge_qns: List[qrules.conservation_rules.GParityEdgeInput], interaction_qns: qrules.conservation_rules.GParityNodeInput) -> bool>: 3,
#                       <function qrules.conservation_rules.isospin_conservation(ingoing_isospins: List[qrules.conservation_rules.IsoSpinEdgeInput], outgoing_isospins: List[qrules.conservation_rules.IsoSpinEdgeInput]) -> bool>: 60,
#                       <function qrules.conservation_rules.ls_spin_validity(spin_input: qrules.conservation_rules.SpinNodeInput) -> bool>: 89,
#                       <function qrules.conservation_rules.helicity_conservation(ingoing_spin_mags: List[qrules.quantum_numbers.EdgeQuantumNumbers.spin_magnitude], outgoing_helicities: List[qrules.quantum_numbers.EdgeQuantumNumbers.spin_projection]) -> bool>: 7,
#                       <function qrules.conservation_rules.parity_conservation_helicity(ingoing_edge_qns: List[qrules.conservation_rules.HelicityParityEdgeInput], outgoing_edge_qns: List[qrules.conservation_rules.HelicityParityEdgeInput], parity_prefactor: qrules.quantum_numbers.NodeQuantumNumbers.parity_prefactor) -> bool>: 4,
#                       <function qrules.conservation_rules.identical_particle_symmetrization(ingoing_parities: List[qrules.quantum_numbers.EdgeQuantumNumbers.parity], outgoing_edge_qns: List[qrules.conservation_rules.IdenticalParticleSymmetryOutEdgeInput]) -> bool>: 2},
#                      qn_domains={qrules.quantum_numbers.NodeQuantumNumbers.l_magnitude: [0,
#                        1],
#                       qrules.quantum_numbers.NodeQuantumNumbers.s_magnitude: [0,
#                        0.5,
#                        1,
#                        1.5,
#                        2]},
#                      interaction_strength=0.0001,
#                    ),
#                    1: NodeSettings(
#                      conservation_rules={<function qrules.conservation_rules.helicity_conservation(ingoing_spin_mags: List[qrules.quantum_numbers.EdgeQuantumNumbers.spin_magnitude], outgoing_helicities: List[qrules.quantum_numbers.EdgeQuantumNumbers.spin_projection]) -> bool>,
#                       <function qrules.conservation_rules.identical_particle_symmetrization(ingoing_parities: List[qrules.quantum_numbers.EdgeQuantumNumbers.parity], outgoing_edge_qns: List[qrules.conservation_rules.IdenticalParticleSymmetryOutEdgeInput]) -> bool>,
#                       <function qrules.conservation_rules.spin_magnitude_conservation(ingoing_spins: List[qrules.conservation_rules.SpinEdgeInput], outgoing_spins: List[qrules.conservation_rules.SpinEdgeInput], interaction_qns: qrules.conservation_rules.SpinMagnitudeNodeInput) -> bool>,
#                       <qrules.conservation_rules.BaryonNumberConservation at 0x15071ca275b0>,
#                       <qrules.conservation_rules.ChargeConservation at 0x15071ca27490>,
#                       <qrules.conservation_rules.ElectronLNConservation at 0x15071ca27610>,
#                       <qrules.conservation_rules.MassConservation at 0x15071ca274f0>,
#                       <qrules.conservation_rules.MuonLNConservation at 0x15071ca27670>,
#                       <qrules.conservation_rules.TauLNConservation at 0x15071ca27550>},
#                      rule_priorities={qrules.conservation_rules.MassConservation: 10,
#                       qrules.conservation_rules.ElectronLNConservation: 45,
#                       qrules.conservation_rules.MuonLNConservation: 44,
#                       qrules.conservation_rules.TauLNConservation: 43,
#                       qrules.conservation_rules.BaryonNumberConservation: 90,
#                       qrules.conservation_rules.StrangenessConservation: 69,
#                       qrules.conservation_rules.CharmConservation: 70,
#                       qrules.conservation_rules.BottomnessConservation: 68,
#                       qrules.conservation_rules.ChargeConservation: 100,
#                       <function qrules.conservation_rules.spin_conservation(ingoing_spins: List[qrules.conservation_rules.SpinEdgeInput], outgoing_spins: List[qrules.conservation_rules.SpinEdgeInput], interaction_qns: qrules.conservation_rules.SpinNodeInput) -> bool>: 8,
#                       <function qrules.conservation_rules.spin_magnitude_conservation(ingoing_spins: List[qrules.conservation_rules.SpinEdgeInput], outgoing_spins: List[qrules.conservation_rules.SpinEdgeInput], interaction_qns: qrules.conservation_rules.SpinMagnitudeNodeInput) -> bool>: 8,
#                       <function qrules.conservation_rules.parity_conservation(ingoing_edge_qns: List[qrules.quantum_numbers.EdgeQuantumNumbers.parity], outgoing_edge_qns: List[qrules.quantum_numbers.EdgeQuantumNumbers.parity], l_magnitude: qrules.quantum_numbers.NodeQuantumNumbers.l_magnitude) -> bool>: 6,
#                       <function qrules.conservation_rules.c_parity_conservation(ingoing_edge_qns: List[qrules.conservation_rules.CParityEdgeInput], outgoing_edge_qns: List[qrules.conservation_rules.CParityEdgeInput], interaction_node_qns: qrules.conservation_rules.CParityNodeInput) -> bool>: 5,
#                       <function qrules.conservation_rules.g_parity_conservation(ingoing_edge_qns: List[qrules.conservation_rules.GParityEdgeInput], outgoing_edge_qns: List[qrules.conservation_rules.GParityEdgeInput], interaction_qns: qrules.conservation_rules.GParityNodeInput) -> bool>: 3,
#                       <function qrules.conservation_rules.isospin_conservation(ingoing_isospins: List[qrules.conservation_rules.IsoSpinEdgeInput], outgoing_isospins: List[qrules.conservation_rules.IsoSpinEdgeInput]) -> bool>: 60,
#                       <function qrules.conservation_rules.ls_spin_validity(spin_input: qrules.conservation_rules.SpinNodeInput) -> bool>: 89,
#                       <function qrules.conservation_rules.helicity_conservation(ingoing_spin_mags: List[qrules.quantum_numbers.EdgeQuantumNumbers.spin_magnitude], outgoing_helicities: List[qrules.quantum_numbers.EdgeQuantumNumbers.spin_projection]) -> bool>: 7,
#                       <function qrules.conservation_rules.parity_conservation_helicity(ingoing_edge_qns: List[qrules.conservation_rules.HelicityParityEdgeInput], outgoing_edge_qns: List[qrules.conservation_rules.HelicityParityEdgeInput], parity_prefactor: qrules.quantum_numbers.NodeQuantumNumbers.parity_prefactor) -> bool>: 4,
#                       <function qrules.conservation_rules.identical_particle_symmetrization(ingoing_parities: List[qrules.quantum_numbers.EdgeQuantumNumbers.parity], outgoing_edge_qns: List[qrules.conservation_rules.IdenticalParticleSymmetryOutEdgeInput]) -> bool>: 2},
#                      qn_domains={qrules.quantum_numbers.NodeQuantumNumbers.l_magnitude: [0,
#                        1],
#                       qrules.quantum_numbers.NodeQuantumNumbers.s_magnitude: [0,
#                        0.5,
#                        1,
#                        1.5,
#                        2]},
#                      interaction_strength=0.0001,
#                    )},
#                 ),
#               ),
#               ProblemSet(
#                 topology=Topology(
#                   nodes=frozenset({0, 1}),
#                   edges=FrozenDict({
#                     -2: Edge(originating_node_id=None, ending_node_id=0),
#                     -1: Edge(originating_node_id=None, ending_node_id=0),
#                     0: Edge(originating_node_id=1, ending_node_id=None),
#                     1: Edge(originating_node_id=1, ending_node_id=None),
#                     2: Edge(originating_node_id=1, ending_node_id=None),
#                     3: Edge(originating_node_id=0, ending_node_id=1),
#                   }),
#                 ),
#                 initial_facts=MutableTransition(
#                   topology=Topology(
#                     nodes=frozenset({0, 1}),
#                     edges=FrozenDict({
#                       -2: Edge(originating_node_id=None, ending_node_id=0),
#                       -1: Edge(originating_node_id=None, ending_node_id=0),
#                       0: Edge(originating_node_id=1, ending_node_id=None),
#                       1: Edge(originating_node_id=1, ending_node_id=None),
#                       2: Edge(originating_node_id=1, ending_node_id=None),
#                       3: Edge(originating_node_id=0, ending_node_id=1),
#                     }),
#                   ),
#                   states={-2: (Particle(
#                       name='p',
#                       pid=2212,
#                       latex='p',
#                       spin=0.5,
#                       mass=0.93827208816,
#                       charge=1,
#                       isospin=Spin(1/2, +1/2),
#                       baryon_number=1,
#                       parity=+1,
#                     ),
#                     -0.5),
#                    -1: (Particle(
#                       name='p',
#                       pid=2212,
#                       latex='p',
#                       spin=0.5,
#                       mass=0.93827208816,
#                       charge=1,
#                       isospin=Spin(1/2, +1/2),
#                       baryon_number=1,
#                       parity=+1,
#                     ),
#                     -0.5),
#                    0: (Particle(
#                       name='d',
#                       pid=9999999,
#                       spin=1.0,
#                       mass=1.87561294257,
#                       isospin=Spin(0, 0),
#                       c_parity=+1,
#                     ),
#                     -1.0),
#                    1: (Particle(
#                       name='e+',
#                       pid=-11,
#                       latex='e^{+}',
#                       spin=0.5,
#                       mass=0.0005109989499999999,
#                       charge=1,
#                       electron_lepton_number=-1,
#                       parity=-1,
#                     ),
#                     -0.5),
#                    2: (Particle(
#                       name='nu(e)',
#                       pid=12,
#                       latex='\\nu_{e}',
#                       spin=0.5,
#                       mass=0.0,
#                       electron_lepton_number=1,
#                       parity=+1,
#                     ),
#                     0.5)},
#                   interactions={},
#                 ),
#                 solving_settings=MutableTransition(
#                   topology=Topology(
#                     nodes=frozenset({0, 1}),
#                     edges=FrozenDict({
#                       -2: Edge(originating_node_id=None, ending_node_id=0),
#                       -1: Edge(originating_node_id=None, ending_node_id=0),
#                       0: Edge(originating_node_id=1, ending_node_id=None),
#                       1: Edge(originating_node_id=1, ending_node_id=None),
#                       2: Edge(originating_node_id=1, ending_node_id=None),
#                       3: Edge(originating_node_id=0, ending_node_id=1),
#                     }),
#                   ),
#                   states={-2: EdgeSettings(
#                      conservation_rules={<function qrules.conservation_rules.gellmann_nishijima(edge_qns: qrules.conservation_rules.GellMannNishijimaInput) -> bool>,
#                       <function qrules.conservation_rules.isospin_validity(isospin: qrules.conservation_rules.IsoSpinEdgeInput) -> bool>,
#                       <function qrules.conservation_rules.spin_validity(spin: qrules.conservation_rules.SpinEdgeInput) -> bool>},
#                      rule_priorities={<function qrules.conservation_rules.gellmann_nishijima(edge_qns: qrules.conservation_rules.GellMannNishijimaInput) -> bool>: 50,
#                       <function qrules.conservation_rules.isospin_validity(isospin: qrules.conservation_rules.IsoSpinEdgeInput) -> bool>: 61,
#                       <function qrules.conservation_rules.spin_validity(spin: qrules.conservation_rules.SpinEdgeInput) -> bool>: 62},
#                      qn_domains={},
#                    ),
#                    -1: EdgeSettings(
#                      conservation_rules={<function qrules.conservation_rules.gellmann_nishijima(edge_qns: qrules.conservation_rules.GellMannNishijimaInput) -> bool>,
#                       <function qrules.conservation_rules.isospin_validity(isospin: qrules.conservation_rules.IsoSpinEdgeInput) -> bool>,
#                       <function qrules.conservation_rules.spin_validity(spin: qrules.conservation_rules.SpinEdgeInput) -> bool>},
#                      rule_priorities={<function qrules.conservation_rules.gellmann_nishijima(edge_qns: qrules.conservation_rules.GellMannNishijimaInput) -> bool>: 50,
#                       <function qrules.conservation_rules.isospin_validity(isospin: qrules.conservation_rules.IsoSpinEdgeInput) -> bool>: 61,
#                       <function qrules.conservation_rules.spin_validity(spin: qrules.conservation_rules.SpinEdgeInput) -> bool>: 62},
#                      qn_domains={},
#                    ),
#                    0: EdgeSettings(
#                      conservation_rules={<function qrules.conservation_rules.gellmann_nishijima(edge_qns: qrules.conservation_rules.GellMannNishijimaInput) -> bool>,
#                       <function qrules.conservation_rules.isospin_validity(isospin: qrules.conservation_rules.IsoSpinEdgeInput) -> bool>,
#                       <function qrules.conservation_rules.spin_validity(spin: qrules.conservation_rules.SpinEdgeInput) -> bool>},
#                      rule_priorities={<function qrules.conservation_rules.gellmann_nishijima(edge_qns: qrules.conservation_rules.GellMannNishijimaInput) -> bool>: 50,
#                       <function qrules.conservation_rules.isospin_validity(isospin: qrules.conservation_rules.IsoSpinEdgeInput) -> bool>: 61,
#                       <function qrules.conservation_rules.spin_validity(spin: qrules.conservation_rules.SpinEdgeInput) -> bool>: 62},
#                      qn_domains={},
#                    ),
#                    1: EdgeSettings(
#                      conservation_rules={<function qrules.conservation_rules.gellmann_nishijima(edge_qns: qrules.conservation_rules.GellMannNishijimaInput) -> bool>,
#                       <function qrules.conservation_rules.isospin_validity(isospin: qrules.conservation_rules.IsoSpinEdgeInput) -> bool>,
#                       <function qrules.conservation_rules.spin_validity(spin: qrules.conservation_rules.SpinEdgeInput) -> bool>},
#                      rule_priorities={<function qrules.conservation_rules.gellmann_nishijima(edge_qns: qrules.conservation_rules.GellMannNishijimaInput) -> bool>: 50,
#                       <function qrules.conservation_rules.isospin_validity(isospin: qrules.conservation_rules.IsoSpinEdgeInput) -> bool>: 61,
#                       <function qrules.conservation_rules.spin_validity(spin: qrules.conservation_rules.SpinEdgeInput) -> bool>: 62},
#                      qn_domains={},
#                    ),
#                    2: EdgeSettings(
#                      conservation_rules={<function qrules.conservation_rules.gellmann_nishijima(edge_qns: qrules.conservation_rules.GellMannNishijimaInput) -> bool>,
#                       <function qrules.conservation_rules.isospin_validity(isospin: qrules.conservation_rules.IsoSpinEdgeInput) -> bool>,
#                       <function qrules.conservation_rules.spin_validity(spin: qrules.conservation_rules.SpinEdgeInput) -> bool>},
#                      rule_priorities={<function qrules.conservation_rules.gellmann_nishijima(edge_qns: qrules.conservation_rules.GellMannNishijimaInput) -> bool>: 50,
#                       <function qrules.conservation_rules.isospin_validity(isospin: qrules.conservation_rules.IsoSpinEdgeInput) -> bool>: 61,
#                       <function qrules.conservation_rules.spin_validity(spin: qrules.conservation_rules.SpinEdgeInput) -> bool>: 62},
#                      qn_domains={},
#                    ),
#                    3: EdgeSettings(
#                      conservation_rules={<function qrules.conservation_rules.gellmann_nishijima(edge_qns: qrules.conservation_rules.GellMannNishijimaInput) -> bool>,
#                       <function qrules.conservation_rules.isospin_validity(isospin: qrules.conservation_rules.IsoSpinEdgeInput) -> bool>,
#                       <function qrules.conservation_rules.spin_validity(spin: qrules.conservation_rules.SpinEdgeInput) -> bool>},
#                      rule_priorities={<function qrules.conservation_rules.gellmann_nishijima(edge_qns: qrules.conservation_rules.GellMannNishijimaInput) -> bool>: 50,
#                       <function qrules.conservation_rules.isospin_validity(isospin: qrules.conservation_rules.IsoSpinEdgeInput) -> bool>: 61,
#                       <function qrules.conservation_rules.spin_validity(spin: qrules.conservation_rules.SpinEdgeInput) -> bool>: 62},
#                      qn_domains={qrules.quantum_numbers.EdgeQuantumNumbers.electron_lepton_number: [-1,
#                        0,
#                        1],
#                       qrules.quantum_numbers.EdgeQuantumNumbers.muon_lepton_number: [-1,
#                        0,
#                        1],
#                       qrules.quantum_numbers.EdgeQuantumNumbers.tau_lepton_number: [-1,
#                        0,
#                        1],
#                       qrules.quantum_numbers.EdgeQuantumNumbers.parity: [-1,
#                        1],
#                       qrules.quantum_numbers.EdgeQuantumNumbers.c_parity: [-1,
#                        1,
#                        None],
#                       qrules.quantum_numbers.EdgeQuantumNumbers.g_parity: [-1,
#                        1,
#                        None],
#                       qrules.quantum_numbers.EdgeQuantumNumbers.charge: [-2,
#                        -1,
#                        0,
#                        1,
#                        2],
#                       qrules.quantum_numbers.EdgeQuantumNumbers.baryon_number: [-1,
#                        0,
#                        1],
#                       qrules.quantum_numbers.EdgeQuantumNumbers.strangeness: [-3,
#                        -2,
#                        -1,
#                        0,
#                        1,
#                        2,
#                        3],
#                       qrules.quantum_numbers.EdgeQuantumNumbers.charmness: [-1,
#                        0,
#                        1],
#                       qrules.quantum_numbers.EdgeQuantumNumbers.bottomness: [-1,
#                        0,
#                        1],
#                       qrules.quantum_numbers.EdgeQuantumNumbers.spin_magnitude: [0,
#                        0.5,
#                        1,
#                        1.5,
#                        2,
#                        2.5,
#                        3,
#                        3.5,
#                        4],
#                       qrules.quantum_numbers.EdgeQuantumNumbers.spin_projection: [-4,
#                        -3.5,
#                        -3,
#                        -2.5,
#                        -2,
#                        -1.5,
#                        -1,
#                        -0.5,
#                        0,
#                        0.5,
#                        1,
#                        1.5,
#                        2,
#                        2.5,
#                        3,
#                        3.5,
#                        4],
#                       qrules.quantum_numbers.EdgeQuantumNumbers.isospin_magnitude: [0,
#                        0.5,
#                        1,
#                        1.5],
#                       qrules.quantum_numbers.EdgeQuantumNumbers.isospin_projection: [-1.5,
#                        -1,
#                        -0.5,
#                        0,
#                        0.5,
#                        1,
#                        1.5]},
#                    )},
#                   interactions={0: NodeSettings(
#                      conservation_rules={<function qrules.conservation_rules.helicity_conservation(ingoing_spin_mags: List[qrules.quantum_numbers.EdgeQuantumNumbers.spin_magnitude], outgoing_helicities: List[qrules.quantum_numbers.EdgeQuantumNumbers.spin_projection]) -> bool>,
#                       <function qrules.conservation_rules.identical_particle_symmetrization(ingoing_parities: List[qrules.quantum_numbers.EdgeQuantumNumbers.parity], outgoing_edge_qns: List[qrules.conservation_rules.IdenticalParticleSymmetryOutEdgeInput]) -> bool>,
#                       <function qrules.conservation_rules.spin_magnitude_conservation(ingoing_spins: List[qrules.conservation_rules.SpinEdgeInput], outgoing_spins: List[qrules.conservation_rules.SpinEdgeInput], interaction_qns: qrules.conservation_rules.SpinMagnitudeNodeInput) -> bool>,
#                       <qrules.conservation_rules.BaryonNumberConservation at 0x15071ca2c1c0>,
#                       <qrules.conservation_rules.ChargeConservation at 0x15071ca2c2e0>,
#                       <qrules.conservation_rules.ElectronLNConservation at 0x15071ca2c220>,
#                       <qrules.conservation_rules.MassConservation at 0x15071ca2c100>,
#                       <qrules.conservation_rules.MuonLNConservation at 0x15071ca2c280>,
#                       <qrules.conservation_rules.TauLNConservation at 0x15071ca2c160>},
#                      rule_priorities={qrules.conservation_rules.MassConservation: 10,
#                       qrules.conservation_rules.ElectronLNConservation: 45,
#                       qrules.conservation_rules.MuonLNConservation: 44,
#                       qrules.conservation_rules.TauLNConservation: 43,
#                       qrules.conservation_rules.BaryonNumberConservation: 90,
#                       qrules.conservation_rules.StrangenessConservation: 69,
#                       qrules.conservation_rules.CharmConservation: 70,
#                       qrules.conservation_rules.BottomnessConservation: 68,
#                       qrules.conservation_rules.ChargeConservation: 100,
#                       <function qrules.conservation_rules.spin_conservation(ingoing_spins: List[qrules.conservation_rules.SpinEdgeInput], outgoing_spins: List[qrules.conservation_rules.SpinEdgeInput], interaction_qns: qrules.conservation_rules.SpinNodeInput) -> bool>: 8,
#                       <function qrules.conservation_rules.spin_magnitude_conservation(ingoing_spins: List[qrules.conservation_rules.SpinEdgeInput], outgoing_spins: List[qrules.conservation_rules.SpinEdgeInput], interaction_qns: qrules.conservation_rules.SpinMagnitudeNodeInput) -> bool>: 8,
#                       <function qrules.conservation_rules.parity_conservation(ingoing_edge_qns: List[qrules.quantum_numbers.EdgeQuantumNumbers.parity], outgoing_edge_qns: List[qrules.quantum_numbers.EdgeQuantumNumbers.parity], l_magnitude: qrules.quantum_numbers.NodeQuantumNumbers.l_magnitude) -> bool>: 6,
#                       <function qrules.conservation_rules.c_parity_conservation(ingoing_edge_qns: List[qrules.conservation_rules.CParityEdgeInput], outgoing_edge_qns: List[qrules.conservation_rules.CParityEdgeInput], interaction_node_qns: qrules.conservation_rules.CParityNodeInput) -> bool>: 5,
#                       <function qrules.conservation_rules.g_parity_conservation(ingoing_edge_qns: List[qrules.conservation_rules.GParityEdgeInput], outgoing_edge_qns: List[qrules.conservation_rules.GParityEdgeInput], interaction_qns: qrules.conservation_rules.GParityNodeInput) -> bool>: 3,
#                       <function qrules.conservation_rules.isospin_conservation(ingoing_isospins: List[qrules.conservation_rules.IsoSpinEdgeInput], outgoing_isospins: List[qrules.conservation_rules.IsoSpinEdgeInput]) -> bool>: 60,
#                       <function qrules.conservation_rules.ls_spin_validity(spin_input: qrules.conservation_rules.SpinNodeInput) -> bool>: 89,
#                       <function qrules.conservation_rules.helicity_conservation(ingoing_spin_mags: List[qrules.quantum_numbers.EdgeQuantumNumbers.spin_magnitude], outgoing_helicities: List[qrules.quantum_numbers.EdgeQuantumNumbers.spin_projection]) -> bool>: 7,
#                       <function qrules.conservation_rules.parity_conservation_helicity(ingoing_edge_qns: List[qrules.conservation_rules.HelicityParityEdgeInput], outgoing_edge_qns: List[qrules.conservation_rules.HelicityParityEdgeInput], parity_prefactor: qrules.quantum_numbers.NodeQuantumNumbers.parity_prefactor) -> bool>: 4,
#                       <function qrules.conservation_rules.identical_particle_symmetrization(ingoing_parities: List[qrules.quantum_numbers.EdgeQuantumNumbers.parity], outgoing_edge_qns: List[qrules.conservation_rules.IdenticalParticleSymmetryOutEdgeInput]) -> bool>: 2},
#                      qn_domains={qrules.quantum_numbers.NodeQuantumNumbers.l_magnitude: [0,
#                        1],
#                       qrules.quantum_numbers.NodeQuantumNumbers.s_magnitude: [0,
#                        0.5,
#                        1,
#                        1.5,
#                        2]},
#                      interaction_strength=0.0001,
#                    ),
#                    1: NodeSettings(
#                      conservation_rules={<function qrules.conservation_rules.helicity_conservation(ingoing_spin_mags: List[qrules.quantum_numbers.EdgeQuantumNumbers.spin_magnitude], outgoing_helicities: List[qrules.quantum_numbers.EdgeQuantumNumbers.spin_projection]) -> bool>,
#                       <function qrules.conservation_rules.identical_particle_symmetrization(ingoing_parities: List[qrules.quantum_numbers.EdgeQuantumNumbers.parity], outgoing_edge_qns: List[qrules.conservation_rules.IdenticalParticleSymmetryOutEdgeInput]) -> bool>,
#                       <function qrules.conservation_rules.spin_magnitude_conservation(ingoing_spins: List[qrules.conservation_rules.SpinEdgeInput], outgoing_spins: List[qrules.conservation_rules.SpinEdgeInput], interaction_qns: qrules.conservation_rules.SpinMagnitudeNodeInput) -> bool>,
#                       <qrules.conservation_rules.BaryonNumberConservation at 0x15071ca2c460>,
#                       <qrules.conservation_rules.ChargeConservation at 0x15071ca2c340>,
#                       <qrules.conservation_rules.ElectronLNConservation at 0x15071ca2c4c0>,
#                       <qrules.conservation_rules.MassConservation at 0x15071ca2c3a0>,
#                       <qrules.conservation_rules.MuonLNConservation at 0x15071ca2c520>,
#                       <qrules.conservation_rules.TauLNConservation at 0x15071ca2c400>},
#                      rule_priorities={qrules.conservation_rules.MassConservation: 10,
#                       qrules.conservation_rules.ElectronLNConservation: 45,
#                       qrules.conservation_rules.MuonLNConservation: 44,
#                       qrules.conservation_rules.TauLNConservation: 43,
#                       qrules.conservation_rules.BaryonNumberConservation: 90,
#                       qrules.conservation_rules.StrangenessConservation: 69,
#                       qrules.conservation_rules.CharmConservation: 70,
#                       qrules.conservation_rules.BottomnessConservation: 68,
#                       qrules.conservation_rules.ChargeConservation: 100,
#                       <function qrules.conservation_rules.spin_conservation(ingoing_spins: List[qrules.conservation_rules.SpinEdgeInput], outgoing_spins: List[qrules.conservation_rules.SpinEdgeInput], interaction_qns: qrules.conservation_rules.SpinNodeInput) -> bool>: 8,
#                       <function qrules.conservation_rules.spin_magnitude_conservation(ingoing_spins: List[qrules.conservation_rules.SpinEdgeInput], outgoing_spins: List[qrules.conservation_rules.SpinEdgeInput], interaction_qns: qrules.conservation_rules.SpinMagnitudeNodeInput) -> bool>: 8,
#                       <function qrules.conservation_rules.parity_conservation(ingoing_edge_qns: List[qrules.quantum_numbers.EdgeQuantumNumbers.parity], outgoing_edge_qns: List[qrules.quantum_numbers.EdgeQuantumNumbers.parity], l_magnitude: qrules.quantum_numbers.NodeQuantumNumbers.l_magnitude) -> bool>: 6,
#                       <function qrules.conservation_rules.c_parity_conservation(ingoing_edge_qns: List[qrules.conservation_rules.CParityEdgeInput], outgoing_edge_qns: List[qrules.conservation_rules.CParityEdgeInput], interaction_node_qns: qrules.conservation_rules.CParityNodeInput) -> bool>: 5,
#                       <function qrules.conservation_rules.g_parity_conservation(ingoing_edge_qns: List[qrules.conservation_rules.GParityEdgeInput], outgoing_edge_qns: List[qrules.conservation_rules.GParityEdgeInput], interaction_qns: qrules.conservation_rules.GParityNodeInput) -> bool>: 3,
#                       <function qrules.conservation_rules.isospin_conservation(ingoing_isospins: List[qrules.conservation_rules.IsoSpinEdgeInput], outgoing_isospins: List[qrules.conservation_rules.IsoSpinEdgeInput]) -> bool>: 60,
#                       <function qrules.conservation_rules.ls_spin_validity(spin_input: qrules.conservation_rules.SpinNodeInput) -> bool>: 89,
#                       <function qrules.conservation_rules.helicity_conservation(ingoing_spin_mags: List[qrules.quantum_numbers.EdgeQuantumNumbers.spin_magnitude], outgoing_helicities: List[qrules.quantum_numbers.EdgeQuantumNumbers.spin_projection]) -> bool>: 7,
#                       <function qrules.conservation_rules.parity_conservation_helicity(ingoing_edge_qns: List[qrules.conservation_rules.HelicityParityEdgeInput], outgoing_edge_qns: List[qrules.conservation_rules.HelicityParityEdgeInput], parity_prefactor: qrules.quantum_numbers.NodeQuantumNumbers.parity_prefactor) -> bool>: 4,
#                       <function qrules.conservation_rules.identical_particle_symmetrization(ingoing_parities: List[qrules.quantum_numbers.EdgeQuantumNumbers.parity], outgoing_edge_qns: List[qrules.conservation_rules.IdenticalParticleSymmetryOutEdgeInput]) -> bool>: 2},
#                      qn_domains={qrules.quantum_numbers.NodeQuantumNumbers.l_magnitude: [0,
#                        1],
#                       qrules.quantum_numbers.NodeQuantumNumbers.s_magnitude: [0,
#                        0.5,
#                        1,
#                        1.5,
#                        2]},
#                      interaction_strength=0.0001,
#                    )},
#                 ),
#               ),
#               ProblemSet(
#                 topology=Topology(
#                   nodes=frozenset({0, 1}),
#                   edges=FrozenDict({
#                     -2: Edge(originating_node_id=None, ending_node_id=0),
#                     -1: Edge(originating_node_id=None, ending_node_id=0),
#                     0: Edge(originating_node_id=1, ending_node_id=None),
#                     1: Edge(originating_node_id=1, ending_node_id=None),
#                     2: Edge(originating_node_id=1, ending_node_id=None),
#                     3: Edge(originating_node_id=0, ending_node_id=1),
#                   }),
#                 ),
#                 initial_facts=MutableTransition(
#                   topology=Topology(
#                     nodes=frozenset({0, 1}),
#                     edges=FrozenDict({
#                       -2: Edge(originating_node_id=None, ending_node_id=0),
#                       -1: Edge(originating_node_id=None, ending_node_id=0),
#                       0: Edge(originating_node_id=1, ending_node_id=None),
#                       1: Edge(originating_node_id=1, ending_node_id=None),
#                       2: Edge(originating_node_id=1, ending_node_id=None),
#                       3: Edge(originating_node_id=0, ending_node_id=1),
#                     }),
#                   ),
#                   states={-2: (Particle(
#                       name='p',
#                       pid=2212,
#                       latex='p',
#                       spin=0.5,
#                       mass=0.93827208816,
#                       charge=1,
#                       isospin=Spin(1/2, +1/2),
#                       baryon_number=1,
#                       parity=+1,
#                     ),
#                     -0.5),
#                    -1: (Particle(
#                       name='p',
#                       pid=2212,
#                       latex='p',
#                       spin=0.5,
#                       mass=0.93827208816,
#                       charge=1,
#                       isospin=Spin(1/2, +1/2),
#                       baryon_number=1,
#                       parity=+1,
#                     ),
#                     -0.5),
#                    0: (Particle(
#                       name='d',
# ...
#                       <function qrules.conservation_rules.isospin_validity(isospin: qrules.conservation_rules.IsoSpinEdgeInput) -> bool>,
#                       <function qrules.conservation_rules.spin_validity(spin: qrules.conservation_rules.SpinEdgeInput) -> bool>},
#                      rule_priorities={<function qrules.conservation_rules.gellmann_nishijima(edge_qns: qrules.conservation_rules.GellMannNishijimaInput) -> bool>: 50,
#                       <function qrules.conservation_rules.isospin_validity(isospin: qrules.conservation_rules.IsoSpinEdgeInput) -> bool>: 61,
#                       <function qrules.conservation_rules.spin_validity(spin: qrules.conservation_rules.SpinEdgeInput) -> bool>: 62},
#                      qn_domains={},
#                    ),
#                    2: EdgeSettings(
#                      conservation_rules={<function qrules.conservation_rules.gellmann_nishijima(edge_qns: qrules.conservation_rules.GellMannNishijimaInput) -> bool>,
#                       <function qrules.conservation_rules.isospin_validity(isospin: qrules.conservation_rules.IsoSpinEdgeInput) -> bool>,
#                       <function qrules.conservation_rules.spin_validity(spin: qrules.conservation_rules.SpinEdgeInput) -> bool>},
#                      rule_priorities={<function qrules.conservation_rules.gellmann_nishijima(edge_qns: qrules.conservation_rules.GellMannNishijimaInput) -> bool>: 50,
#                       <function qrules.conservation_rules.isospin_validity(isospin: qrules.conservation_rules.IsoSpinEdgeInput) -> bool>: 61,
#                       <function qrules.conservation_rules.spin_validity(spin: qrules.conservation_rules.SpinEdgeInput) -> bool>: 62},
#                      qn_domains={},
#                    ),
#                    3: EdgeSettings(
#                      conservation_rules={<function qrules.conservation_rules.gellmann_nishijima(edge_qns: qrules.conservation_rules.GellMannNishijimaInput) -> bool>,
#                       <function qrules.conservation_rules.isospin_validity(isospin: qrules.conservation_rules.IsoSpinEdgeInput) -> bool>,
#                       <function qrules.conservation_rules.spin_validity(spin: qrules.conservation_rules.SpinEdgeInput) -> bool>},
#                      rule_priorities={<function qrules.conservation_rules.gellmann_nishijima(edge_qns: qrules.conservation_rules.GellMannNishijimaInput) -> bool>: 50,
#                       <function qrules.conservation_rules.isospin_validity(isospin: qrules.conservation_rules.IsoSpinEdgeInput) -> bool>: 61,
#                       <function qrules.conservation_rules.spin_validity(spin: qrules.conservation_rules.SpinEdgeInput) -> bool>: 62},
#                      qn_domains={qrules.quantum_numbers.EdgeQuantumNumbers.electron_lepton_number: [-1,
#                        0,
#                        1],
#                       qrules.quantum_numbers.EdgeQuantumNumbers.muon_lepton_number: [-1,
#                        0,
#                        1],
#                       qrules.quantum_numbers.EdgeQuantumNumbers.tau_lepton_number: [-1,
#                        0,
#                        1],
#                       qrules.quantum_numbers.EdgeQuantumNumbers.parity: [-1,
#                        1],
#                       qrules.quantum_numbers.EdgeQuantumNumbers.c_parity: [-1,
#                        1,
#                        None],
#                       qrules.quantum_numbers.EdgeQuantumNumbers.g_parity: [-1,
#                        1,
#                        None],
#                       qrules.quantum_numbers.EdgeQuantumNumbers.charge: [-2,
#                        -1,
#                        0,
#                        1,
#                        2],
#                       qrules.quantum_numbers.EdgeQuantumNumbers.baryon_number: [-1,
#                        0,
#                        1],
#                       qrules.quantum_numbers.EdgeQuantumNumbers.strangeness: [-3,
#                        -2,
#                        -1,
#                        0,
#                        1,
#                        2,
#                        3],
#                       qrules.quantum_numbers.EdgeQuantumNumbers.charmness: [-1,
#                        0,
#                        1],
#                       qrules.quantum_numbers.EdgeQuantumNumbers.bottomness: [-1,
#                        0,
#                        1],
#                       qrules.quantum_numbers.EdgeQuantumNumbers.spin_magnitude: [0,
#                        0.5,
#                        1,
#                        1.5,
#                        2,
#                        2.5,
#                        3,
#                        3.5,
#                        4],
#                       qrules.quantum_numbers.EdgeQuantumNumbers.spin_projection: [-4,
#                        -3.5,
#                        -3,
#                        -2.5,
#                        -2,
#                        -1.5,
#                        -1,
#                        -0.5,
#                        0,
#                        0.5,
#                        1,
#                        1.5,
#                        2,
#                        2.5,
#                        3,
#                        3.5,
#                        4],
#                       qrules.quantum_numbers.EdgeQuantumNumbers.isospin_magnitude: [0,
#                        0.5,
#                        1,
#                        1.5],
#                       qrules.quantum_numbers.EdgeQuantumNumbers.isospin_projection: [-1.5,
#                        -1,
#                        -0.5,
#                        0,
#                        0.5,
#                        1,
#                        1.5]},
#                    )},
#                   interactions={0: NodeSettings(
#                      conservation_rules={<function qrules.conservation_rules.helicity_conservation(ingoing_spin_mags: List[qrules.quantum_numbers.EdgeQuantumNumbers.spin_magnitude], outgoing_helicities: List[qrules.quantum_numbers.EdgeQuantumNumbers.spin_projection]) -> bool>,
#                       <function qrules.conservation_rules.identical_particle_symmetrization(ingoing_parities: List[qrules.quantum_numbers.EdgeQuantumNumbers.parity], outgoing_edge_qns: List[qrules.conservation_rules.IdenticalParticleSymmetryOutEdgeInput]) -> bool>,
#                       <function qrules.conservation_rules.spin_magnitude_conservation(ingoing_spins: List[qrules.conservation_rules.SpinEdgeInput], outgoing_spins: List[qrules.conservation_rules.SpinEdgeInput], interaction_qns: qrules.conservation_rules.SpinMagnitudeNodeInput) -> bool>,
#                       <qrules.conservation_rules.BaryonNumberConservation at 0x15071ca57160>,
#                       <qrules.conservation_rules.ChargeConservation at 0x15071ca57280>,
#                       <qrules.conservation_rules.ElectronLNConservation at 0x15071ca57220>,
#                       <qrules.conservation_rules.MassConservation at 0x15071ca571f0>,
#                       <qrules.conservation_rules.MuonLNConservation at 0x15071ca57250>,
#                       <qrules.conservation_rules.TauLNConservation at 0x15071ca571c0>},
#                      rule_priorities={qrules.conservation_rules.MassConservation: 10,
#                       qrules.conservation_rules.ElectronLNConservation: 45,
#                       qrules.conservation_rules.MuonLNConservation: 44,
#                       qrules.conservation_rules.TauLNConservation: 43,
#                       qrules.conservation_rules.BaryonNumberConservation: 90,
#                       qrules.conservation_rules.StrangenessConservation: 69,
#                       qrules.conservation_rules.CharmConservation: 70,
#                       qrules.conservation_rules.BottomnessConservation: 68,
#                       qrules.conservation_rules.ChargeConservation: 100,
#                       <function qrules.conservation_rules.spin_conservation(ingoing_spins: List[qrules.conservation_rules.SpinEdgeInput], outgoing_spins: List[qrules.conservation_rules.SpinEdgeInput], interaction_qns: qrules.conservation_rules.SpinNodeInput) -> bool>: 8,
#                       <function qrules.conservation_rules.spin_magnitude_conservation(ingoing_spins: List[qrules.conservation_rules.SpinEdgeInput], outgoing_spins: List[qrules.conservation_rules.SpinEdgeInput], interaction_qns: qrules.conservation_rules.SpinMagnitudeNodeInput) -> bool>: 8,
#                       <function qrules.conservation_rules.parity_conservation(ingoing_edge_qns: List[qrules.quantum_numbers.EdgeQuantumNumbers.parity], outgoing_edge_qns: List[qrules.quantum_numbers.EdgeQuantumNumbers.parity], l_magnitude: qrules.quantum_numbers.NodeQuantumNumbers.l_magnitude) -> bool>: 6,
#                       <function qrules.conservation_rules.c_parity_conservation(ingoing_edge_qns: List[qrules.conservation_rules.CParityEdgeInput], outgoing_edge_qns: List[qrules.conservation_rules.CParityEdgeInput], interaction_node_qns: qrules.conservation_rules.CParityNodeInput) -> bool>: 5,
#                       <function qrules.conservation_rules.g_parity_conservation(ingoing_edge_qns: List[qrules.conservation_rules.GParityEdgeInput], outgoing_edge_qns: List[qrules.conservation_rules.GParityEdgeInput], interaction_qns: qrules.conservation_rules.GParityNodeInput) -> bool>: 3,
#                       <function qrules.conservation_rules.isospin_conservation(ingoing_isospins: List[qrules.conservation_rules.IsoSpinEdgeInput], outgoing_isospins: List[qrules.conservation_rules.IsoSpinEdgeInput]) -> bool>: 60,
#                       <function qrules.conservation_rules.ls_spin_validity(spin_input: qrules.conservation_rules.SpinNodeInput) -> bool>: 89,
#                       <function qrules.conservation_rules.helicity_conservation(ingoing_spin_mags: List[qrules.quantum_numbers.EdgeQuantumNumbers.spin_magnitude], outgoing_helicities: List[qrules.quantum_numbers.EdgeQuantumNumbers.spin_projection]) -> bool>: 7,
#                       <function qrules.conservation_rules.parity_conservation_helicity(ingoing_edge_qns: List[qrules.conservation_rules.HelicityParityEdgeInput], outgoing_edge_qns: List[qrules.conservation_rules.HelicityParityEdgeInput], parity_prefactor: qrules.quantum_numbers.NodeQuantumNumbers.parity_prefactor) -> bool>: 4,
#                       <function qrules.conservation_rules.identical_particle_symmetrization(ingoing_parities: List[qrules.quantum_numbers.EdgeQuantumNumbers.parity], outgoing_edge_qns: List[qrules.conservation_rules.IdenticalParticleSymmetryOutEdgeInput]) -> bool>: 2},
#                      qn_domains={qrules.quantum_numbers.NodeQuantumNumbers.l_magnitude: [0,
#                        1],
#                       qrules.quantum_numbers.NodeQuantumNumbers.s_magnitude: [0,
#                        0.5,
#                        1,
#                        1.5,
#                        2]},
#                      interaction_strength=0.0001,
#                    ),
#                    1: NodeSettings(
#                      conservation_rules={<function qrules.conservation_rules.helicity_conservation(ingoing_spin_mags: List[qrules.quantum_numbers.EdgeQuantumNumbers.spin_magnitude], outgoing_helicities: List[qrules.quantum_numbers.EdgeQuantumNumbers.spin_projection]) -> bool>,
#                       <function qrules.conservation_rules.identical_particle_symmetrization(ingoing_parities: List[qrules.quantum_numbers.EdgeQuantumNumbers.parity], outgoing_edge_qns: List[qrules.conservation_rules.IdenticalParticleSymmetryOutEdgeInput]) -> bool>,
#                       <function qrules.conservation_rules.spin_magnitude_conservation(ingoing_spins: List[qrules.conservation_rules.SpinEdgeInput], outgoing_spins: List[qrules.conservation_rules.SpinEdgeInput], interaction_qns: qrules.conservation_rules.SpinMagnitudeNodeInput) -> bool>,
#                       <qrules.conservation_rules.BaryonNumberConservation at 0x15071ca572b0>,
#                       <qrules.conservation_rules.ChargeConservation at 0x15071ca570d0>,
#                       <qrules.conservation_rules.ElectronLNConservation at 0x15071ca572e0>,
#                       <qrules.conservation_rules.MassConservation at 0x15071ca56cb0>,
#                       <qrules.conservation_rules.MuonLNConservation at 0x15071ca57310>,
#                       <qrules.conservation_rules.TauLNConservation at 0x15071ca56c50>},
#                      rule_priorities={qrules.conservation_rules.MassConservation: 10,
#                       qrules.conservation_rules.ElectronLNConservation: 45,
#                       qrules.conservation_rules.MuonLNConservation: 44,
#                       qrules.conservation_rules.TauLNConservation: 43,
#                       qrules.conservation_rules.BaryonNumberConservation: 90,
#                       qrules.conservation_rules.StrangenessConservation: 69,
#                       qrules.conservation_rules.CharmConservation: 70,
#                       qrules.conservation_rules.BottomnessConservation: 68,
#                       qrules.conservation_rules.ChargeConservation: 100,
#                       <function qrules.conservation_rules.spin_conservation(ingoing_spins: List[qrules.conservation_rules.SpinEdgeInput], outgoing_spins: List[qrules.conservation_rules.SpinEdgeInput], interaction_qns: qrules.conservation_rules.SpinNodeInput) -> bool>: 8,
#                       <function qrules.conservation_rules.spin_magnitude_conservation(ingoing_spins: List[qrules.conservation_rules.SpinEdgeInput], outgoing_spins: List[qrules.conservation_rules.SpinEdgeInput], interaction_qns: qrules.conservation_rules.SpinMagnitudeNodeInput) -> bool>: 8,
#                       <function qrules.conservation_rules.parity_conservation(ingoing_edge_qns: List[qrules.quantum_numbers.EdgeQuantumNumbers.parity], outgoing_edge_qns: List[qrules.quantum_numbers.EdgeQuantumNumbers.parity], l_magnitude: qrules.quantum_numbers.NodeQuantumNumbers.l_magnitude) -> bool>: 6,
#                       <function qrules.conservation_rules.c_parity_conservation(ingoing_edge_qns: List[qrules.conservation_rules.CParityEdgeInput], outgoing_edge_qns: List[qrules.conservation_rules.CParityEdgeInput], interaction_node_qns: qrules.conservation_rules.CParityNodeInput) -> bool>: 5,
#                       <function qrules.conservation_rules.g_parity_conservation(ingoing_edge_qns: List[qrules.conservation_rules.GParityEdgeInput], outgoing_edge_qns: List[qrules.conservation_rules.GParityEdgeInput], interaction_qns: qrules.conservation_rules.GParityNodeInput) -> bool>: 3,
#                       <function qrules.conservation_rules.isospin_conservation(ingoing_isospins: List[qrules.conservation_rules.IsoSpinEdgeInput], outgoing_isospins: List[qrules.conservation_rules.IsoSpinEdgeInput]) -> bool>: 60,
#                       <function qrules.conservation_rules.ls_spin_validity(spin_input: qrules.conservation_rules.SpinNodeInput) -> bool>: 89,
#                       <function qrules.conservation_rules.helicity_conservation(ingoing_spin_mags: List[qrules.quantum_numbers.EdgeQuantumNumbers.spin_magnitude], outgoing_helicities: List[qrules.quantum_numbers.EdgeQuantumNumbers.spin_projection]) -> bool>: 7,
#                       <function qrules.conservation_rules.parity_conservation_helicity(ingoing_edge_qns: List[qrules.conservation_rules.HelicityParityEdgeInput], outgoing_edge_qns: List[qrules.conservation_rules.HelicityParityEdgeInput], parity_prefactor: qrules.quantum_numbers.NodeQuantumNumbers.parity_prefactor) -> bool>: 4,
#                       <function qrules.conservation_rules.identical_particle_symmetrization(ingoing_parities: List[qrules.quantum_numbers.EdgeQuantumNumbers.parity], outgoing_edge_qns: List[qrules.conservation_rules.IdenticalParticleSymmetryOutEdgeInput]) -> bool>: 2},
#                      qn_domains={qrules.quantum_numbers.NodeQuantumNumbers.l_magnitude: [0,
#                        1],
#                       qrules.quantum_numbers.NodeQuantumNumbers.s_magnitude: [0,
#                        0.5,
#                        1,
#                        1.5,
#                        2]},
#                      interaction_strength=0.0001,
#                    )},
#                 ),
#               )]})

# %%
reaction = stm.find_solutions(problem_sets)

dot = qrules.io.asdot(reaction, collapse_graphs=True)
graphviz.Source(dot)
# Out:
# Propagating quantum numbers:   0%|          | 0/48 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeWarning                            Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 reaction = stm.find_solutions(problem_sets)
#       3 dot = qrules.io.asdot(reaction, collapse_graphs=True)
#       4 graphviz.Source(dot)
#
# File /project/agkuhr/users/dkoch/python-packages-for-physics/physics-venv/lib/python3.10/site-packages/qrules/transition.py:578, in StateTransitionManager.find_solutions(self, problem_sets)
#     576     for rules in execution_info.not_executed_node_rules.values():
#     577         not_executed_rules |= rules
# --> 578     raise RuntimeWarning(
#     579         "There are conservation rules that were not executed: "
#     580         + ", ".join(not_executed_rules)
#     581     )
#     582 if not final_solutions:
#     583     raise ValueError("No solutions were found")
#
# RuntimeWarning: There are conservation rules that were not executed: identical_particle_symmetrization, gellmann_nishijima, isospin_validity, helicity_conservation, spin_magnitude_conservation, BaryonNumberConservation, spin_validity, MassConservation
